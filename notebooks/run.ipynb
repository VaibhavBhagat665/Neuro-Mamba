# %% [markdown]
# # 🧠 Neuro-Mamba Shielded Control Agent
#
# ## Google Colab Execution Environment
# This notebook is designed to run the Neuro-Mamba project on Google Colab.
#
# ### Step 1: Factory Reset Runtime & Enable GPU
# 1. Go to `Runtime` -> `Change runtime type`
# 2. Select `T4 GPU` (or `L4` / `A100` if you have Pro)
# 3. Click `Save`
#
# ### Step 2: Clone from GitHub
# Run the cell below to clone the project directly from GitHub.

# %%
# Replace 'YOUR_USERNAME' with your actual GitHub username
# !git clone https://github.com/VaibhavBhagat665/Neuro-Mamba
# %cd neuro-mamba

# %% [markdown]
# ### Step 3: Install Dependencies (Mamba & Safety-Gymnasium)
# Colab comes with PyTorch pre-installed. We just need to install the Mamba SSM dependencies and Safety Gymnasium.

# %%
# Install core math/optimization dependencies
# !pip install osqp cvxpy

# Install safety gymnasium
# !pip install safety-gymnasium==0.4.0 gymnasium==0.29.0

# Install mamba (this takes ~3-5 minutes to compile CUDA kernels)
# !pip install causal-conv1d>=1.1.0
# !pip install mamba-ssm==1.2.0

# Utilities
# !pip install wandb stable-baselines3 sb3-contrib imageio imageio-ffmpeg

# %% [markdown]
# ### Step 4: Run the Training
# You're all set! Let's start training Variant E (Neuro-Mamba with CBF Shield and Safety Hallucination).

# %%
# !python scripts/train_mamba.py --variant E --timesteps 100000
